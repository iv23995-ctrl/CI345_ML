# %% [markdown]
# # Lab05 - Classification using KNN

# %%
# %matplotlib inline
import random
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(5, 4))

# %%
from sklearn.datasets import load_digits
digits = load_digits()
#print(digits.DESCR)

# %%
# Show the data part
digits.data.shape
# Out:
# (1797, 64)

# %%
#First image
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
digits.target.shape
# Out:
# (1797,)

# %%
digits.target[0]
# Out:
# 0

# %%
digits.images[1]
# Out:
# array([[ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16.,  9.,  0.,  0.],
#        [ 0.,  0.,  3., 15., 16.,  6.,  0.,  0.],
#        [ 0.,  7., 15., 16., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  3.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16., 10.,  0.,  0.]])

# %%
digits.target[1]
# Out:
# 1

# %%
# 
import matplotlib.pyplot as plt
axes = plt.subplot()
image = plt.imshow(digits.images[1], cmap = plt.cm.gray_r)

# %%
#Secon image
digits.data[1]
# Out:
# array([ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.,  0.,  0.,  0., 11., 16.,
#         9.,  0.,  0.,  0.,  0.,  3., 15., 16.,  6.,  0.,  0.,  0.,  7.,
#        15., 16., 16.,  2.,  0.,  0.,  0.,  0.,  1., 16., 16.,  3.,  0.,
#         0.,  0.,  0.,  1., 16., 16.,  6.,  0.,  0.,  0.,  0.,  1., 16.,
#        16.,  6.,  0.,  0.,  0.,  0.,  0., 11., 16., 10.,  0.,  0.])

# %%
# Three record
#digits.data[0:3]

# %%
# Three target
digits.target[0:3]
# Out:
# array([0, 1, 2])

# %%
df = digits.target
len(df)
df
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
import numpy as np

# Load the digits dataset
digits = load_digits()

# Get the target labels
targets = digits.target

# Count the occurrences of each digit
unique, counts = np.unique(targets, return_counts=True)

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(unique, counts, color='grey')
plt.xticks(unique, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Digits', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.title('Counts of Digits in Optical Recognition Dataset', fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the chart
plt.show()

# %%
# Step 2  Splitting the data from training and testing

from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(digits.data, digits.target, random_state = 11, test_size =0.2)

# %%
# In your exam, you need show the output
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1437, 64)
# (360, 64)
# (1437,)
# (360,)

# %%
# Step 3 Creating the Model
from sklearn.neighbors import KNeighborsClassifier

knn= KNeighborsClassifier()

knn.fit(X = X_train, y = y_train)
# Out:
# KNeighborsClassifier()

# %%
# Step 4 Prediciting
predicted = knn.predict(X = X_test)

predicted
# Out:
# array([0, 4, 9, 9, 3, 1, 4, 1, 5, 0, 4, 9, 4, 1, 5, 3, 3, 8, 5, 6])

# %%
# Compare the results
expected = y_test
expected

# %%
print(predicted[:30])
print(expected[:30])
# Out:
# [0 4 9 9 3 1 4 1 5 0 4 9 4 1 5 3 3 8 5 6 9 6 0 6 9 3 2 1 8 1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-edd1c18518aa> in <module>
#       1 print(Predicted[:30])
# ----> 2 print(Expected[:30])
#
# NameError: name 'Expected' is not defined

# %%
wrong = []
for p, e in zip (redicted, Expected):
    if p != e:
        wrong.append((p,e))

print(wrong)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a33026642419> in <module>
#       1 wrong = []
# ----> 2 for p, e in zip (Predicted, Expected):
#       3     if p != e:
#       4         wrong.append((p,e))
#       5
#
# NameError: name 'Expected' is not defined

# %% [markdown]
# # Lab07 - Classification Evaluation
# Macias Ivory - Jones
#
# 4/29/26

# %%
# Caculate and display accurage
accuracy = (len(Predicted) - len(wrong))/len(Predicted)
print(accuracy)
print(format(accuracy, '.2%'))
print(f'{accuracy:.2%}')
# Out:
# 1.0
# 100.00%
# 100.00%

# %%
# Evaluate the results
accuracy = knn.score( X_test,y_test)
print(accuracy)
# Out:
# 0.9861111111111112

# %%
# Confusion Matrix

from sklearn.metrics import confusion_matrix

matrix = confusion_matrix(y_true = expected, y_pred = Predicted)
print(matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ee139376f008> in <module>
#       3 from sklearn.metrics import confusion_matrix
#       4
# ----> 5 matrix = confusion_matrix(y_true = expected, y_pred = Predicted)
#       6 print(matrix)
#       7
#
# NameError: name 'expected' is not defined

# %%
# Which digits have the perfect predication

# Which digits have the worst predication

# %%
from sklearn.metrics import classification_report

report = classification_report(expected, Predicted)
print(report)

# %%
import panda as pd

matrix_df =  pd.DataFrame(matrix)

import seaborn as sns
sns.heatmap(matrix_df, annot = True)
